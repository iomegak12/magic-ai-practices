# %%
import os
from dotenv import load_dotenv
from typing import Any

from azure.identity import AzureCliCredential
from agent_framework.azure import AzureOpenAIResponsesClient

from agent_framework import Message, WorkflowEvent
from agent_framework.orchestrations import ConcurrentBuilder

# %%
load_dotenv(override=True)

project_endpoint = os.getenv("AZURE_AI_PROJECT_ENDPOINT")
model = os.getenv("AZURE_OPENAI_RESPONSES_DEPLOYMENT_NAME")

print("Project Endpoint: ", project_endpoint)
print("Model: ", model)
# Out:
# Project Endpoint:  https://jdramkumar32-1674-resource.services.ai.azure.com/api/projects/jdramkumar32-1674
# Model:  gpt-4o

# %%
credential = AzureCliCredential()
chat_client = AzureOpenAIResponsesClient(
    project_endpoint=project_endpoint,
    deployment_name=model,
    credential=credential,
)

# %%
from agent_framework import Agent

researcher = Agent(
    name="Researcher",
    description="Collects relevant background information.",
    instructions="Gather concise facts that help answer the question. Be brief and factual.",
    client=chat_client,
)

writer = Agent(
    name="Writer",
    description="Synthesizes polished answers using gathered information.",
    instructions="Compose clear, structured answers using any notes provided. Be comprehensive.",
    client=chat_client,
)

orchestrator_agent = Agent(
    name="Orchestrator",
    description="Coordinates multi-agent collaboration by selecting speakers",
    instructions="""
You coordinate a team conversation to solve the user's task.

Guidelines:
- Start with Researcher to gather information
- Then have Writer synthesize the final answer
- Only finish after both have contributed meaningfully
""",
    client=chat_client,
)

# %%
from agent_framework.orchestrations import GroupChatBuilder, GroupChatState

def round_robin_selector(state: GroupChatState) -> str:
    """A round-robin selector function that picks the next speaker based on the current round index."""

    participant_names = list(state.participants.keys())
    return participant_names[state.current_round % len(participant_names)]


# Build the group chat workflow
workflow = GroupChatBuilder(
    participants=[researcher, writer],
    termination_condition=lambda conversation: len(conversation) >= 4,
    selection_func=round_robin_selector,
).build()

# %%
from typing import cast
from agent_framework import AgentResponseUpdate, Role

task = "What are the key benefits of async/await in Python?"

print(f"Task: {task}\n")
print("=" * 80)

final_conversation: list[Message] = []
last_executor_id: str | None = None

# Run the workflow
async for event in workflow.run(task, stream=True):
    if event.type == "output" and isinstance(event.data, AgentResponseUpdate):
        # Print streaming agent updates
        eid = event.executor_id
        if eid != last_executor_id:
            if last_executor_id is not None:
                print()
            print(f"[{eid}]:", end=" ", flush=True)
            last_executor_id = eid
        print(event.data, end="", flush=True)
    elif event.type == "output":
        # Workflow completed - data is a list of Message
        final_conversation = cast(list[Message], event.data)

if final_conversation:
    print("\n\n" + "=" * 80)
    print("Final Conversation:")
    for msg in final_conversation:
        author = getattr(msg, "author_name", "Unknown")
        text = getattr(msg, "text", str(msg))
        print(f"\n[{author}]\n{text}")
        print("-" * 80)

print("\nWorkflow completed.")
# Out:
# Task: What are the key benefits of async/await in Python?
#
# ================================================================================
#
#
# ================================================================================
# Final Conversation:
#
# [None]
# What are the key benefits of async/await in Python?
# --------------------------------------------------------------------------------
#
# [Researcher]
# 1. **Improved Readability:** Async/await syntax is more intuitive and resembles synchronous code, making it easier to understand and maintain.
#
# 2. **Concurrency:** Enables concurrent execution of I/O-bound tasks without blocking, improving efficiency in applications like web servers.
#
# 3. **Non-Blocking:** Prevents blocking of the main thread, allowing other tasks to run simultaneously while waiting for I/O operations.
#
# 4. **Reduced Callback Hell:** Simplifies asynchronous code management by avoiding deeply nested callbacks.
#
# 5. **Better Exception Handling:** Allows the use of try/except blocks around asynchronous calls, improving error handling compared to callback-based approaches.
#
# 6. **Compatibility:** Integrates well with existing Python features and libraries that support asynchronous programming, such as `asyncio`.
# --------------------------------------------------------------------------------
#
# [Writer]
# Async/await in Python offers several key benefits:
#
# 1. **Improved Readability:** The syntax closely resembles synchronous code, making it easier to understand and write. This clarity helps maintain and debug code efficiently.
#
# 2. **Concurrency:** It facilitates concurrent execution of I/O-bound tasks, allowing multiple operations to be managed simultaneously, which boosts performance in applications like web servers and data fetching.
#
# 3. **Non-Blocking Operations:** Async/await allows the main thread to remain responsive while waiting for I/O operations to complete. This means other tasks can proceed without delay.
#
# 4. **Simplification of Asynchronous Code:** By reducing reliance on callbacks, async/await minimizes the complexity associated with "callback hell," providing a cleaner flow of logic.
#
# 5. **Enhanced Exception Handling:** Async/await supports try/except blocks around asynchronous calls, allowing for robust error management unlike traditional callback methods.
#
# 6. **Integration with Python Ecosystem:** It is well-supported by Python's `asyncio` library and complements other asynchronous frameworks and libraries, facilitating seamless integration into existing projects.
# --------------------------------------------------------------------------------
#
# [Researcher]
# Async/await in Python offers several key benefits:
#
# 1. **Improved Readability:** The syntax is intuitive and resembles synchronous code, making it easier to understand and maintain.
#
# 2. **Concurrency:** Facilitates concurrent execution of I/O-bound tasks, enhancing efficiency in handling multiple operations.
#
# 3. **Non-Blocking Operations:** Keeps the main thread responsive, allowing other tasks to run while waiting for I/O operations.
#
# 4. **Simplified Asynchronous Code:** Reduces "callback hell" by providing a cleaner and more structured code flow.
#
# 5. **Enhanced Exception Handling:** Supports try/except blocks around async calls, improving error management.
#
# 6. **Integration with Python Ecosystem:** Works seamlessly with Python's `asyncio` and other asynchronous frameworks, allowing easy integration.
# --------------------------------------------------------------------------------
#
# [group_chat_orchestrator]
# The group chat has reached its termination condition.
# --------------------------------------------------------------------------------
#
# Workflow completed.

# %%
# Build group chat with agent-based orchestrator
workflow = GroupChatBuilder(
    participants=[researcher, writer],
    # Set a hard termination condition: stop after 4 assistant messages
    # The agent orchestrator will intelligently decide when to end before this limit but just in case
    termination_condition=lambda messages: sum(1 for msg in messages if msg.role == "assistant") >= 5,
    orchestrator_agent=orchestrator_agent,
).build()

# %%
from typing import cast
from agent_framework import AgentResponseUpdate, Role

task = "What are the key benefits of async/await in Python?"

print(f"Task: {task}\n")
print("=" * 80)

final_conversation: list[Message] = []
last_executor_id: str | None = None

# Run the workflow
async for event in workflow.run(task, stream=True):
    if event.type == "output" and isinstance(event.data, AgentResponseUpdate):
        # Print streaming agent updates
        eid = event.executor_id
        if eid != last_executor_id:
            if last_executor_id is not None:
                print()
            print(f"[{eid}]:", end=" ", flush=True)
            last_executor_id = eid
        print(event.data, end="", flush=True)
    elif event.type == "output":
        # Workflow completed - data is a list of Message
        final_conversation = cast(list[Message], event.data)

if final_conversation:
    print("\n\n" + "=" * 80)
    print("Final Conversation:")
    for msg in final_conversation:
        author = getattr(msg, "author_name", "Unknown")
        text = getattr(msg, "text", str(msg))
        print(f"\n[{author}]\n{text}")
        print("-" * 80)

print("\nWorkflow completed.")
# Out:
# Task: What are the key benefits of async/await in Python?
#
# ================================================================================
#
#
# ================================================================================
# Final Conversation:
#
# [None]
# What are the key benefits of async/await in Python?
# --------------------------------------------------------------------------------
#
# [Researcher]
# 1. **Improved Readability**: Async/await syntax makes asynchronous code look similar to synchronous code, enhancing readability.
#
# 2. **Simplified Syntax**: Reduces the complexity compared to callback-based programming, making asynchronous programming more accessible.
#
# 3. **Efficient I/O**: Allows non-blocking, concurrent I/O operations, improving performance in I/O-bound applications.
#
# 4. **Error Handling**: Offers better error handling over traditional threading, with clearer exception propagation.
#
# 5. **Single-Threaded Concurrency**: Enables concurrent execution within a single thread, minimizing overhead compared to multi-threading.
#
# 6. **Easier Debugging**: Provides clearer stack traces and easier debugging compared to callback-based patterns.
#
# 7. **Built-in Support**: Integrates smoothly with Python's event loop in asyncio, leveraging existing libraries and utilities.
# --------------------------------------------------------------------------------
#
# [Writer]
# Here’s a closer look at the key benefits of using `async/await` in Python:
#
# 1. **Improved Readability**: The syntax allows asynchronous code to be structured similarly to synchronous code, making it easier to understand and write.
#
# 2. **Simplified Syntax**: It reduces the complexity compared to callback-based programming, making asynchronous operations more intuitive and straightforward.
#
# 3. **Efficient I/O**: `async/await` enables non-blocking I/O operations, allowing your program to handle multiple I/O-bound tasks concurrently without waiting for each to complete sequentially.
#
# 4. **Error Handling**: Provides better error handling mechanisms compared to traditional threading, with clear exception propagation and management.
#
# 5. **Single-Threaded Concurrency**: Facilitates concurrent execution within a single thread, reducing overhead associated with multi-threading and avoiding common threading issues.
#
# 6. **Easier Debugging**: Enhances debugging capabilities by offering clearer stack traces and more control over asynchronous operations compared to callbacks.
#
# 7. **Built-in Support**: Seamlessly integrates with Python's asyncio library, leveraging existing event loop mechanisms, libraries, and utilities to efficiently manage asynchronous tasks.
#
# These benefits collectively make `async/await` a powerful tool for developers dealing with asynchronous and I/O-bound programming challenges.
# --------------------------------------------------------------------------------
#
# [Orchestrator]
# Async/await in Python enhances readability, simplifies syntax, improves I/O efficiency, and offers robust error handling and debugging capabilities. It also supports single-threaded concurrency and integrates well with asyncio, making it ideal for I/O-bound applications.
# --------------------------------------------------------------------------------
#
# Workflow completed.
