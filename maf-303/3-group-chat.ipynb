# %%
import os
from dotenv import load_dotenv
from typing import Any

from azure.identity import AzureCliCredential
from agent_framework.azure import AzureOpenAIResponsesClient

from agent_framework import Message, WorkflowEvent
from agent_framework.orchestrations import ConcurrentBuilder

# %%
load_dotenv(override=True)

project_endpoint = os.getenv("AZURE_AI_PROJECT_ENDPOINT")
model = os.getenv("AZURE_OPENAI_RESPONSES_DEPLOYMENT_NAME")

print("Project Endpoint: ", project_endpoint)
print("Model: ", model)
# Out:
# Project Endpoint:  https://agentic-team-foundry-resource.services.ai.azure.com/api/projects/agentic-team-foundry-project
# Model:  gpt-4o

# %%
credential = AzureCliCredential()
chat_client = AzureOpenAIResponsesClient(
    project_endpoint=project_endpoint,
    deployment_name=model,
    credential=credential,
)

# %%
from agent_framework import Agent

researcher = Agent(
    name="Researcher",
    description="Collects relevant background information.",
    instructions="Gather concise facts that help answer the question. Be brief and factual.",
    client=chat_client,
)

writer = Agent(
    name="Writer",
    description="Synthesizes polished answers using gathered information.",
    instructions="Compose clear, structured answers using any notes provided. Be comprehensive.",
    client=chat_client,
)

orchestrator_agent = Agent(
    name="Orchestrator",
    description="Coordinates multi-agent collaboration by selecting speakers",
    instructions="""
You coordinate a team conversation to solve the user's task.

Guidelines:
- Start with Researcher to gather information
- Then have Writer synthesize the final answer
- Only finish after both have contributed meaningfully
""",
    client=chat_client,
)

# %%
from agent_framework.orchestrations import GroupChatBuilder, GroupChatState

def round_robin_selector(state: GroupChatState) -> str:
    """A round-robin selector function that picks the next speaker based on the current round index."""

    participant_names = list(state.participants.keys())
    return participant_names[state.current_round % len(participant_names)]


# Build the group chat workflow
workflow = GroupChatBuilder(
    participants=[researcher, writer],
    termination_condition=lambda conversation: len(conversation) >= 4,
    selection_func=round_robin_selector,
).build()

# %%
from typing import cast
from agent_framework import AgentResponseUpdate, Role

task = "What are the key benefits of async/await in Python?"

print(f"Task: {task}\n")
print("=" * 80)

final_conversation: list[Message] = []
last_executor_id: str | None = None

# Run the workflow
async for event in workflow.run(task, stream=True):
    if event.type == "output" and isinstance(event.data, AgentResponseUpdate):
        # Print streaming agent updates
        eid = event.executor_id
        if eid != last_executor_id:
            if last_executor_id is not None:
                print()
            print(f"[{eid}]:", end=" ", flush=True)
            last_executor_id = eid
        print(event.data, end="", flush=True)
    elif event.type == "output":
        # Workflow completed - data is a list of Message
        final_conversation = cast(list[Message], event.data)

if final_conversation:
    print("\n\n" + "=" * 80)
    print("Final Conversation:")
    for msg in final_conversation:
        author = getattr(msg, "author_name", "Unknown")
        text = getattr(msg, "text", str(msg))
        print(f"\n[{author}]\n{text}")
        print("-" * 80)

print("\nWorkflow completed.")
# Out:
# Task: What are the key benefits of async/await in Python?
#
# ================================================================================
#
#
# ================================================================================
# Final Conversation:
#
# [None]
# What are the key benefits of async/await in Python?
# --------------------------------------------------------------------------------
#
# [Researcher]
# 1. **Improved Readability**: Async/await syntax resembles synchronous code, making it more intuitive and easier to understand than older callback-based approaches.
#
# 2. **Concurrency**: Allows non-blocking operations, enabling efficient asynchronous I/O-bound tasks without multi-threading, leading to better scalability in I/O-heavy applications.
#
# 3. **Simplified Code**: Reduces boilerplate compared to the traditional use of callbacks and `yield` in generators, leading to cleaner and more maintainable code.
#
# 4. **Error Handling**: Provides a straightforward way to handle exceptions in asynchronous code, similar to synchronous code using try/except blocks.
#
# 5. **Performance**: Optimizes resource utilization by pausing tasks while waiting for external processes (like network responses), allowing other tasks to run concurrently.
# --------------------------------------------------------------------------------
#
# [Writer]
# The async/await syntax in Python offers several key benefits:
#
# 1. **Improved Readability**: The syntax mirrors synchronous code, making it intuitive and reducing cognitive load compared to callbacks or generators. This helps developers write and maintain clearer code.
#
# 2. **Concurrency**: It enables efficient handling of I/O-bound tasks by allowing non-blocking operations. This lets you perform multiple tasks simultaneously without the need for multi-threading, enhancing scalability in applications that rely on I/O operations.
#
# 3. **Simplified Code**: Async/await reduces the need for boilerplate code associated with traditional asynchronous patterns, such as callbacks or the use of `yield` in generators. This leads to cleaner, more maintainable code.
#
# 4. **Error Handling**: By aligning closely with synchronous error handling, it simplifies the management of exceptions in asynchronous code using standard try/except blocks.
#
# 5. **Performance**: By pausing tasks during I/O operations and allowing other tasks to run concurrently, async/await optimizes resource utilization, improving overall application performance.
# --------------------------------------------------------------------------------
#
# [Researcher]
# What are the key benefits of async/await in Python?
# --------------------------------------------------------------------------------
#
# [group_chat_orchestrator]
# The group chat has reached its termination condition.
# --------------------------------------------------------------------------------
#
# Workflow completed.

# %%
# Build group chat with agent-based orchestrator
workflow = GroupChatBuilder(
    participants=[researcher, writer],
    # Set a hard termination condition: stop after 4 assistant messages
    # The agent orchestrator will intelligently decide when to end before this limit but just in case
    termination_condition=lambda messages: sum(1 for msg in messages if msg.role == "assistant") >= 5,
    orchestrator_agent=orchestrator_agent,
).build()

# %%
from typing import cast
from agent_framework import AgentResponseUpdate, Role

task = "What are the key benefits of async/await in Python?"

print(f"Task: {task}\n")
print("=" * 80)

final_conversation: list[Message] = []
last_executor_id: str | None = None

# Run the workflow
async for event in workflow.run(task, stream=True):
    if event.type == "output" and isinstance(event.data, AgentResponseUpdate):
        # Print streaming agent updates
        eid = event.executor_id
        if eid != last_executor_id:
            if last_executor_id is not None:
                print()
            print(f"[{eid}]:", end=" ", flush=True)
            last_executor_id = eid
        print(event.data, end="", flush=True)
    elif event.type == "output":
        # Workflow completed - data is a list of Message
        final_conversation = cast(list[Message], event.data)

if final_conversation:
    print("\n\n" + "=" * 80)
    print("Final Conversation:")
    for msg in final_conversation:
        author = getattr(msg, "author_name", "Unknown")
        text = getattr(msg, "text", str(msg))
        print(f"\n[{author}]\n{text}")
        print("-" * 80)

print("\nWorkflow completed.")
# Out:
# Task: What are the key benefits of async/await in Python?
#
# ================================================================================
#
#
# ================================================================================
# Final Conversation:
#
# [None]
# What are the key benefits of async/await in Python?
# --------------------------------------------------------------------------------
#
# [Researcher]
# 1. **Simplified Syntax**: Async/await provides a more readable and intuitive syntax for asynchronous programming compared to traditional callbacks.
#
# 2. **Concurrency**: It allows non-blocking code, enabling I/O-bound tasks to execute concurrently without thread management.
#
# 3. **Improved Performance**: Enhances performance in applications dealing with multiple I/O operations, reducing wait times.
#
# 4. **Error Handling**: Simplifies error handling in asynchronous code compared to complex callback chains.
#
# 5. **Structured Code**: Makes asynchronous code resemble synchronous code, improving structure and maintainability.
#
# 6. **Integration**: Seamlessly integrates with existing asynchronous libraries like asyncio.
# --------------------------------------------------------------------------------
#
# [Writer]
# Here are the key benefits of using async/await in Python:
#
# 1. **Simplified Syntax**: Async/await offers a readable and intuitive way to write asynchronous code, making it easier to understand than traditional callback-based approaches.
#
# 2. **Concurrency**: It enables non-blocking execution, allowing I/O-bound tasks to run concurrently without the overhead of managing threads.
#
# 3. **Improved Performance**: By running tasks concurrently, async/await can significantly increase performance for applications that deal with multiple I/O operations, reducing overall wait times.
#
# 4. **Error Handling**: Simplifies error handling by using try/except blocks, avoiding the complexity often associated with callback chains.
#
# 5. **Structured Code**: Async/await helps structure asynchronous code to look more like synchronous code, making it easier to read and maintain.
#
# 6. **Integration**: It works seamlessly with asynchronous libraries like asyncio, enhancing capabilities and simplifying the integration of asynchronous functions.
# --------------------------------------------------------------------------------
#
# [Orchestrator]
# Async/await in Python offers several benefits that enhance asynchronous programming. It provides simplified syntax for easier coding and understanding compared to callbacks. By enabling concurrency, it allows non-blocking I/O operations to run simultaneously, improving performance in I/O-heavy applications. Error handling is streamlined, resembling synchronous code, which leads to better readability and maintainability. Furthermore, async/await integrates effectively with asynchronous libraries like asyncio, allowing seamless implementation for developers seeking performance optimization.
# --------------------------------------------------------------------------------
#
# Workflow completed.
