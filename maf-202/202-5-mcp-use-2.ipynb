# %%
import os
from dotenv import load_dotenv
from agent_framework.azure import AzureOpenAIResponsesClient
from azure.identity.aio import AzureCliCredential
from agent_framework import MCPStreamableHTTPTool

# %%
load_dotenv(override=True)

project_endpoint = os.getenv("AZURE_AI_PROJECT_ENDPOINT")
model = os.getenv("AZURE_OPENAI_RESPONSES_DEPLOYMENT_NAME")

print("Project Endpoint: ", project_endpoint)
print("Model: ", model)
# Out:
# Project Endpoint:  https://agentic-team-foundry-resource.services.ai.azure.com/api/projects/agentic-team-foundry-project
# Model:  gpt-4o

# %%
complaints_management_mcp_tool = MCPStreamableHTTPTool(
    name = "Complaints Management Server",
    url = "http://localhost:8000/mcp"
)

# %%
credential = AzureCliCredential()
client = AzureOpenAIResponsesClient(
    project_endpoint=project_endpoint,
    deployment_name=model,
    credential=credential,
)
agent = client.as_agent(
    name="ComplaintsManagementAgent",
    instructions="You are a helpful assistant that can help with Complaints Management Related activities.",
    tools=[complaints_management_mcp_tool]
)

# %%
session = agent.create_session()

# %%
query = "My name is Ramkumar, i would like to register a complaint regarding the product i purchased last week. Can you please help me with that?"
response = await agent.run(query, session=session)

# %%
print("\nAssistant:\n", response)
# Out:
# Assistant:
#  Of course, Ramkumar! I can help you register a complaint. Please provide the following details:
#
# 1. **Title of the Complaint:** A brief summary of the issue.
# 2. **Description:** A detailed explanation of the problem.
# 3. **Order Number:** The order reference in the format ORD-NNNNN (e.g., ORD-10001).
# 4. **Priority:** Severity level — LOW, MEDIUM, HIGH, or CRITICAL.
# 5. **Remarks:** Any additional notes you wish to include (optional).
#
# Feel free to provide as much detail as you can.

# %%
query = "My delivery has not reached yet, my order number is ORD-128498, if you can resolve this ASAP, that would be great."
response = await agent.run(query, session=session)

# %%
print("\nAssistant:\n", response)
# Out:
# Assistant:
#  Your complaint has been successfully registered with the following details:
#
# - **Title:** Delivery Not Received
# - **Order Number:** ORD-128498
# - **Priority:** HIGH
# - **Status:** OPEN
# - **Complaint ID:** 21
#
# We will work to resolve this as soon as possible. Please let me know if there's anything else I can assist you with.

# %%
query = "can you get me the complete complaint details of #21"
response = await agent.run(query, session=session)
print("\nAssistant:\n", response)
# Out:
# Assistant:
#  Here are the complete details of Complaint #21:
#
# - **Title:** Delivery Not Received
# - **Description:** The delivery for my order has not reached yet. I would appreciate it if this can be resolved as soon as possible.
# - **Customer Name:** Ramkumar
# - **Order Number:** ORD-128498
# - **Created At:** 2026-03-24T14:52:17
# - **Updated At:** 2026-03-24T14:52:17
# - **Priority:** HIGH
# - **Status:** OPEN
# - **Remarks:** None
# - **Archived:** No
#
# If you have any more questions or need further assistance, feel free to ask!

# %%
query = "get all the complaints registered by me"
response = await agent.run(query, session=session)

print("\nAssistant:\n", response)
# Out:
# Assistant:
#  You have one registered complaint:
#
# ### Complaint #21
# - **Title:** Delivery Not Received
# - **Description:** The delivery for your order has not reached yet. You requested it be resolved as soon as possible.
# - **Order Number:** ORD-128498
# - **Created At:** 2026-03-24
# - **Priority:** HIGH
# - **Status:** OPEN
#
# Please let me know if you need further details or assistance!
