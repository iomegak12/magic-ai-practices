# %%
import os
from dotenv import load_dotenv
from agent_framework.openai import OpenAIChatClient
from azure.identity.aio import AzureCliCredential
from agent_framework import MCPStreamableHTTPTool

# %%
load_dotenv(override=True)

azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
model = os.getenv("AZURE_OPENAI_RESPONSES_DEPLOYMENT_NAME")

print("Azure OpenAI Endpoint: ", azure_endpoint)
print("Model: ", model)
# Out:
# Azure OpenAI Endpoint:  https://ramkumar-foundry-v19.services.ai.azure.com
# Model:  gpt-4o

# %%
ms_learn_mcp_tool = MCPStreamableHTTPTool(
    name = "Microsoft Learn MCP Tool",
    url = "https://learn.microsoft.com/api/mcp"
)

# %%
credential = AzureCliCredential()
client = OpenAIChatClient(
    model=model,
    azure_endpoint=azure_endpoint,
    credential=credential,
)
agent = client.as_agent(
    name="DocsAgent",
    instructions="You are a helpful assistant that can help with Microsoft documentation questions.",
    tools=[ms_learn_mcp_tool]
)

# %%
session = agent.create_session()
query = "How to create an Azure storage account using az cli?"

# %%
response = await agent.run(query, session=session)
print("\nAssistant:\n", response)
# Out:
# Assistant:
#  To create an Azure storage account using the Azure CLI, you can use the following command:
#
# ```azurecli
# az storage account create \
#     --name <storage-account-name> \
#     --resource-group <resource-group-name> \
#     --location <location> \
#     --sku Standard_LRS
# ```
#
# ### Example
# ```azurecli
# az storage account create \
#     --name MyStorageAccount \
#     --resource-group MyResourceGroup \
#     --location westus \
#     --sku Standard_LRS
# ```
#
# ### Explanation:
# - `--name`: The name for the new storage account. Must be globally unique.
# - `--resource-group`: The name of the resource group where the storage account will reside.
# - `--location`: The Azure region (for example, `eastus` or `westus`) for the storage account.
# - `--sku`: The SKU (pricing tier) for the storage account, such as `Standard_LRS` for locally redundant storage.
#
# For additional options or features such as `--kind`, `--access-tier`, or `--https-only`, you can refer to [Microsoft's official documentation](https://learn.microsoft.com/azure/digital-twins/tutorial-end-to-end#set-up-the-sample-function-app).
#
# Let me know if you need more details or advanced configurations!
